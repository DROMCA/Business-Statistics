# %% [markdown]
# # GBU 2301 Package Installation
#
# Select the Python environment you intend to use for the course, then run the installation cell. Restart the kernel when installation finishes and run the verification cell.

# %%
# %pip install -r requirements.txt

# %%
from importlib.metadata import version

required_packages = [
    "ipykernel",
    "ipywidgets",
    "jupyterlab",
    "matplotlib",
    "notebook",
    "numpy",
    "openpyxl",
    "pandas",
    "scipy",
    "seaborn",
    "statsmodels"
]

for package in required_packages:
    print(f"{package}: {version(package)}")

print("Course environment is ready.")
